# %% [markdown]
# ## WordCloud

# %%
strings = []
with open("titles_tkde.txt", "r") as file:
    strings = [x.strip().rstrip(".") for x in file.readlines()]
    print(strings)
# Out:
# ['A Framework for Anomaly Detection in Time-Driven and Event-Driven Processes Using Kernel Traces', 'A Survey and Quantitative Study on Map Inference Algorithms From GPS Trajectories', 'A Survey of Data-Driven and Knowledge-Aware eXplainable AI', 'A Survey on Deep Learning for Named Entity Recognition', 'A Survey on Spark Ecosystem: Big Data Processing Infrastructure, Machine Learning, and Applications', 'Accurately Estimating User Cardinalities and Detecting Super Spreaders Over Time', 'Achieving Secure and Dynamic Range Queries Over Encrypted Cloud Data', 'Activity Organization for Friend-Making Optimization in Online Social Networks', 'Aligning Points to Lines: Provable Approximations', 'An Online Robust Support Vector Regression for Data Streams', 'An Optimal Online Semi-Connected PLA Algorithm With Maximum Error Bound', 'Cohesive Subgraph Search Using Keywords in Large Networks', 'Collective Decision for Open Set Recognition', 'Constrained Truth Discovery', 'Copula Guided Parallel Gibbs Sampling for Nonparametric and Coherent Topic Discovery', 'Cost-Sensitive Portfolio Selection via Deep Reinforcement Learning', 'Deep Learning on Graphs: A Survey', 'DGDFS: Dependence Guided Discriminative Feature Selection for Predicting Adverse Drug-Drug Interaction', 'Fast Multi-View Semi-Supervised Learning With Learned Graph', 'Fastest Path Query Answering using Time-Dependent Hop-Labeling in Road Network', 'Hierarchical Prediction and Adversarial Learning For Conditional Response Generation', 'HyperMinHash: MinHash in LogLog Space', 'Label Propagated Nonnegative Matrix Factorization for Clustering', 'Lamps: Location-Aware Moving Top-k Pub/Sub', 'Large Scale Tensor Factorization via Parallel Sketches', 'Learning Vertex Representations for Bipartite Networks', 'Matrix Completion via Schatten Capped $p$p Norm', 'Modeling Dynamic Missingness of Implicit Feedback for Sequential Recommendation', 'RDMN: A Relative Density Measure Based on MST Neighborhood for Clustering Multi-Scale Datasets', 'RHINE: Relation Structure-Aware Heterogeneous Information Network Embedding', 'SoulMate: Short-Text Author Linking Through Multi-Aspect Temporal-Textual Embedding', 'Spatiotemporal Activity Modeling via Hierarchical Cross-Modal Embedding', 'Steerable Self-Driving Data Visualization', 'Subgraph Matching With Effective Matching Order and Indexing', 'A Biclustering Method for Heterogeneous and Temporal Medical Data', 'A Novel Enriched Version of Truncated Nuclear Norm Regularization for Matrix Completion of Inexact Observed Data', 'CHEER: Rich Model Helps Poor Model via Knowledge Infusion', 'Cross-Database Micro-Expression Recognition: A Benchmark', 'Deep Cross-Modal Hashing With Hashing Functions and Unified Hash Codes Jointly Learning', 'Discovering Temporal Patterns for Event Sequence Clustering via Policy Mixture Model', 'Domain Adaptation on Graphs by Learning Aligned Graph Bases', 'Effective Keyword Search Over Weighted Graphs', 'ESA-Stream: Efficient Self-Adaptive Online Data Stream Clustering', 'Evidence Integration for Multi-Hop Reading Comprehension With Graph Neural Networks', 'Exploiting Interpretable Patterns for Flow Prediction in Dockless Bike Sharing Systems', 'Fast and Secure Distributed Nonnegative Matrix Factorization', 'Gaussian Distribution Based Oversampling for Imbalanced Data Classification', 'g-Inspector: Recurrent Attention Model on Graph', 'Hihooi: A Database Replication Middleware for Scaling Transactional Databases Consistently', 'HinCTI: A Cyber Threat Intelligence Modeling and Identification System Based on Heterogeneous Information Network', 'Incorporating Multi-Source Urban Data for Personalized and Context-Aware Multi-Modal Transportation Recommendation', 'Information Fusion for (Re)Configuring Bike Station Networks With Crowdsourcing', 'Linear Approximation of F-Measure for the Performance Evaluation of Classification Algorithms on Imbalanced Data Sets', 'LookCom: Learning Optimal Network for Community Detection', 'Maxi ...

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

# %%
stopwords = set(STOPWORDS)
comment_words = ""

# %%
for word in strings:
    tokens = word.split()
    
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
        
    comment_words += " ".join(tokens)+" "

# %%
print(comment_words)
# Out:
# a framework for anomaly detection in time-driven and event-driven processes using kernel traces a survey and quantitative study on map inference algorithms from gps trajectories a survey of data-driven and knowledge-aware explainable ai a survey on deep learning for named entity recognition a survey on spark ecosystem: big data processing infrastructure, machine learning, and applications accurately estimating user cardinalities and detecting super spreaders over time achieving secure and dynamic range queries over encrypted cloud data activity organization for friend-making optimization in online social networks aligning points to lines: provable approximations an online robust support vector regression for data streams an optimal online semi-connected pla algorithm with maximum error bound cohesive subgraph search using keywords in large networks collective decision for open set recognition constrained truth discovery copula guided parallel gibbs sampling for nonparametric and coherent topic discovery cost-sensitive portfolio selection via deep reinforcement learning deep learning on graphs: a survey dgdfs: dependence guided discriminative feature selection for predicting adverse drug-drug interaction fast multi-view semi-supervised learning with learned graph fastest path query answering using time-dependent hop-labeling in road network hierarchical prediction and adversarial learning for conditional response generation hyperminhash: minhash in loglog space label propagated nonnegative matrix factorization for clustering lamps: location-aware moving top-k pub/sub large scale tensor factorization via parallel sketches learning vertex representations for bipartite networks matrix completion via schatten capped $p$p norm modeling dynamic missingness of implicit feedback for sequential recommendation rdmn: a relative density measure based on mst neighborhood for clustering multi-scale datasets rhine: relation structure-aware heterogeneous information network embedding soulmate: short-text author linking through multi-aspect temporal-textual embedding spatiotemporal activity modeling via hierarchical cross-modal embedding steerable self-driving data visualization subgraph matching with effective matching order and indexing a biclustering method for heterogeneous and temporal medical data a novel enriched version of truncated nuclear norm regularization for matrix completion of inexact observed data cheer: rich model helps poor model via knowledge infusion cross-database micro-expression recognition: a benchmark deep cross-modal hashing with hashing functions and unified hash codes jointly learning discovering temporal patterns for event sequence clustering via policy mixture model domain adaptation on graphs by learning aligned graph bases effective keyword search over weighted graphs esa-stream: efficient self-adaptive online data stream clustering evidence integration for multi-hop reading comprehension with graph neural networks exploiting interpretable patterns for flow prediction in dockless bike sharing systems fast and secure distributed nonnegative matrix factorization gaussian distribution based oversampling for imbalanced data classification g-inspector: recurrent attention model on graph hihooi: a database replication middleware for scaling transactional databases consistently hincti: a cyber threat intelligence modeling and identification system based on heterogeneous information network incorporating multi-source urban data for personalized and context-aware multi-modal transportation recommendation information fusion for (re)configuring bike station networks with crowdsourcing linear approximation of f-measure for the performance evaluation of classification algorithms on imbalanced data sets lookcom: learning optimal network for community detection maximizing the utility in location-based mobile advertising multi-task learning for recommendation over heterogeneous information network multi-view clustering with the ...

# %%
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
